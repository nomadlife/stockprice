# %%
import pandas as pd
import matplotlib
#matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json

with open('krx_total_list.txt','r') as f:
    tickers = json.loads(f.read())
len(tickers)
# Out:
# 2085

# %%
test = pd.read_pickle('./data10y_close_pickle_2/023530')
test.head()
# Out:
#                Close
# Date
# 2008-01-02  392500.0
# 2008-01-03  390500.0
# 2008-01-04  390500.0
# 2008-01-07  390500.0
# 2008-01-08  390500.0

# %%
print(test.shape, tickers['023530']['회사명'])
fig = plt.figure()
ax = plt.axes()
ax.xaxis.set_visible(False)
ax.set_yticklabels([])
test['Close'].plot();
# Out:
# (2703, 1) 롯데쇼핑

# %%
df = pd.DataFrame({'ds':test.index, 'y':test['Close']})
df.tail()
# Out:
#                    ds         y
# Date
# 2018-11-28 2018-11-28  220000.0
# 2018-11-29 2018-11-29  223000.0
# 2018-11-30 2018-11-30  215500.0
# 2018-12-03 2018-12-03  215000.0
# 2018-12-04 2018-12-04  216000.0

# %%
df.head()
# Out:
#                    ds         y
# Date
# 2008-01-02 2008-01-02  392500.0
# 2008-01-03 2008-01-03  390500.0
# 2008-01-04 2008-01-04  390500.0
# 2008-01-07 2008-01-07  390500.0
# 2008-01-08 2008-01-08  390500.0

# %%
from fbprophet import Prophet
m = Prophet(daily_seasonality=True)
m.fit(df);
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3063 2019-11-30
# 3064 2019-12-01
# 3065 2019-12-02
# 3066 2019-12-03
# 3067 2019-12-04

# %%
forecast = m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#              ds           yhat     yhat_lower     yhat_upper
# 3063 2019-11-30  211959.987406  142091.644711  274387.131477
# 3064 2019-12-01  211662.670628  144969.727764  277600.740533
# 3065 2019-12-02  208835.508518  140084.637727  272334.632784
# 3066 2019-12-03  208565.200625  138396.583702  273920.144851
# 3067 2019-12-04  209270.317569  136493.917883  274494.421827

# %%
forecast.ds[2702]
# Out:
# Timestamp('2018-12-04 00:00:00')

# %%
forecast.loc[forecast['ds'] == '2018-12-04']
# Out:
#              ds          trend     yhat_lower     yhat_upper    trend_lower  \
# 2702 2018-12-04  230472.688104  182366.786764  250190.370401  230472.688104
#
#         trend_upper  additive_terms  additive_terms_lower  \
# 2702  230472.688104   -14551.402103         -14551.402103
#
#       additive_terms_upper         daily      ...             weekly  \
# 2702         -14551.402103 -11697.936654      ...       -1064.627528
#
#       weekly_lower  weekly_upper       yearly  yearly_lower  yearly_upper  \
# 2702  -1064.627528  -1064.627528 -1788.837921  -1788.837921  -1788.837921
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 2702                   0.0                         0.0
#
#       multiplicative_terms_upper           yhat
# 2702                         0.0  215921.286001
#
# [1 rows x 22 columns]

# %%
# check forcast
forecast.tail()
# Out:
#              ds          trend     yhat_lower     yhat_upper    trend_lower  \
# 3063 2019-11-30  222883.972304  142091.644711  274387.131477  160251.880665
# 3064 2019-12-01  222862.950930  144969.727764  277600.740533  159931.281209
# 3065 2019-12-02  222841.929557  140084.637727  272334.632784  159616.940119
# 3066 2019-12-03  222820.908183  138396.583702  273920.144851  159339.342635
# 3067 2019-12-04  222799.886810  136493.917883  274494.421827  159130.086060
#
#         trend_upper  additive_terms  additive_terms_lower  \
# 3063  280572.940023   -10923.984897         -10923.984897
# 3064  280852.239928   -11200.280302         -11200.280302
# 3065  281104.383391   -14006.421039         -14006.421039
# 3066  281318.438561   -14255.707559         -14255.707559
# 3067  281523.614344   -13529.569241         -13529.569241
#
#       additive_terms_upper         daily      ...             weekly  \
# 3063         -10923.984897 -11697.936654      ...        1462.242130
# ...

# %%
# check forcast
forecast_new = forecast[['ds','yhat']].copy()
forecast_new.tail()
# Out:
#              ds           yhat
# 3063 2019-11-30  211959.987406
# 3064 2019-12-01  211662.670628
# 3065 2019-12-02  208835.508518
# 3066 2019-12-03  208565.200625
# 3067 2019-12-04  209270.317569

# %%
data1 = pd.DataFrame({'ds':forecast.ds, 'yhat':forecast.yhat})
data1.head()
# Out:
#           ds           yhat
# 0 2008-01-02  376492.290195
# 1 2008-01-03  375656.328722
# 2 2008-01-04  374710.542297
# 3 2008-01-07  371435.047934
# 4 2008-01-08  370459.847084

# %%
data2 = pd.DataFrame({'ds':df.ds, 'y':df.y})
data2.head()
# Out:
#                    ds         y
# Date
# 2008-01-02 2008-01-02  392500.0
# 2008-01-03 2008-01-03  390500.0
# 2008-01-04 2008-01-04  390500.0
# 2008-01-07 2008-01-07  390500.0
# 2008-01-08 2008-01-08  390500.0

# %%
data3 = pd.DataFrame({'ds':df.ds, 'y':df.y})
data3.head()
# Out:
#                    ds         y
# Date
# 2008-01-02 2008-01-02  392500.0
# 2008-01-03 2008-01-03  390500.0
# 2008-01-04 2008-01-04  390500.0
# 2008-01-07 2008-01-07  390500.0
# 2008-01-08 2008-01-08  390500.0

# %%
new_df = pd.DataFrame({'ds':forecast.ds, 'yhat':forecast.yhat, 'y':df.y})
new_df
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py:1217: RuntimeWarning: Cannot compare type 'Timestamp' with type 'int', sort order is undefined for incomparable objects
#   this = Index.union(this, other)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-02d08ebbd7c1> in <module>
# ----> 1 new_df = pd.DataFrame({'ds':df.ds, 'yhat':forecast.yhat, 'y':df.y})
#       2 new_df
#
# ~/anaconda3/envs/prophet/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ...

# %%
test['Close'].plot()

# %%
# figure size test
# plt.figure(figsize=(3,4))
figure = m.plot(forecast);
axes = figure.get_axes()
axes[0].set_xlabel('Date')
axes[0].set_ylabel('test')
# Out:
# Text(41.375, 0.5, 'test')

# %%
m.plot(forecast);

# %%
m.plot_components(forecast)

# %% [markdown]
# # iteration

# %%
def make_prediction(n1, n2):
    cnt = 0;log=[]
    m = Prophet(daily_seasonality=True)
    print('make prediction : {} ~ {}'.format(n1,n2),end='')
    for i,v in tickers.items():
        cnt+=1
        if cnt > n1 and '마켓' in v:
            ticker = i+'.'+v['마켓']
            try:
                data = pd.read_pickle('./data5y/{}-test'.format(ticker))
                m = Prophet(daily_seasonality=True)
                df = pd.DataFrame({'ds':data.index, 'y':data['Close']})
                m.fit(df);
                future = m.make_future_dataframe(periods=365)
                forecast = m.predict(future)
                m.plot(forecast).savefig('./graph5y_predict/{}-test.png'.format(ticker))
                log.append((cnt,ticker,'plotted.',v['회사명']))
                print(cnt,ticker,'.',end='')
            except Exception as e:
                log.append((cnt,ticker,'failed.',e,v['회사명']))
                print(cnt,ticker,'failed',e,v['회사명'])
                pass
        if cnt == n2 :
            break
    print('prediction finished.')
    filename = 'log-predict-{}-{}.txt'.format(n1,n2)
    with open('./graph5y_predict/'+filename, 'w') as f:
        for i in log:
            f.write("{}\n".format(i))
        print(filename,'file saved!')

# %%
make_prediction(5,10)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# make prediction : 5 ~ 10
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# .
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# ...

# %%
# 21 sec
from time import time as t
start = t()

make_prediction(10,15)

print('time:', t()-start)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# make prediction : 10 ~ 15
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# .
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# ...

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(35,55,5))

def call_job(n):
    make_prediction(n,n+5)

pool = Pool(processes=2) # 4개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# ...

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(55,75,5))

def call_job(n):
    make_prediction(n,n+5)

pool = Pool(processes=4) # 4개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# ...

# %%
from time import time as t
start = t()
make_prediction(75,80)
print('time:', t()-start)
# Out:
# make prediction : 75 ~ 80
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# .
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# .
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# .
# ...

# %%
list(range(80,85))
# Out:
# [80, 81, 82, 83, 84]

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(80,85))
def call_job(n):
    make_prediction(n,n+1)
    
pool = Pool(processes=3) # 4개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# make prediction : 81 ~ 82. plotting finished.
# ...

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(85,90))
def call_job(n):
    make_prediction(n,n+1)
    
pool = Pool(processes=2) # 4개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# make prediction : 86 ~ 87. plotting finished.
# log-plot-86-87.txt file saved!
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
# ...

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(90,100,5))
def call_job(n):
    make_prediction(n,n+5)
    
pool = Pool(processes=2) # 4개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# ...

# %%
from time import time as t
start = t()
make_prediction(100,120)
print('time:', t()-start)
# Out:
# make prediction : 100 ~ 120
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# .
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# .
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# .
# ...

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(100,120,5))
def call_job(n):
    make_prediction(n,n+5)
    
pool = Pool(processes=4) # 4개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# ...

# %%
from multiprocessing import Pool
from time import time as t
start = t()

num_list = list(range(100,120))
def call_job(n):
    make_prediction(n,n+1)
    
pool = Pool(processes=3) # n개의 프로세스를 사용합니다.
pool.map(call_job, num_list) # pool에 일을 던져줍니다.
print('time:', t()-start)
# Out:
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# /home/jw/anaconda3/envs/prophet/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# ...
