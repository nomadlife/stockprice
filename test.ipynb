# %%
from datetime import datetime
import pandas_datareader.data as wb

# %%
stocklist = ['AAPL','GOOG','FB','AMZN','COP']

start = datetime(2016,6,8)
end = datetime(2016,6,11)

df = wb.DataReader(stocklist, 'yahoo',start,end)

# %%
start = datetime(2018,11,1)
end = datetime(2018,11,30)

df = wb.DataReader('005930.KS', 'yahoo', start,end)

# %%
df
# Out:
#                High      Low     Open    Close      Volume  Adj Close
# Date
# 2018-11-01  42950.0  42150.0  42450.0  42150.0  13423132.0    42150.0
# 2018-11-02  44250.0  42800.0  43050.0  44150.0  16517112.0    44150.0
# 2018-11-05  43800.0  42900.0  43750.0  43800.0   9426777.0    43800.0
# 2018-11-06  43800.0  42950.0  43750.0  43750.0   7713625.0    43750.0
# 2018-11-07  44500.0  43400.0  43600.0  44000.0  11553998.0    44000.0
# 2018-11-08  45050.0  44050.0  44900.0  44050.0  12617397.0    44050.0
# 2018-11-09  44850.0  43900.0  44450.0  44300.0   7318500.0    44300.0
# 2018-11-12  45250.0  43700.0  43850.0  45200.0   8552566.0    45200.0
# 2018-11-13  44500.0  43400.0  43900.0  44500.0   9311126.0    44500.0
# 2018-11-14  44500.0  43800.0  44500.0  44100.0   6783344.0    44100.0
# 2018-11-15  44350.0  43500.0  44050.0  44250.0   5864067.0    44250.0
# 2018-11-16  44750.0  43700.0  44600.0  44000.0   7777124.0    44000.0
# ...

# %%
df['Close'].plot()

# %%
df['Close'].plot(figsize=(12,6), grid=True);

# %% [markdown]
# # read pickle file

# %%
import pandas as pd
test = pd.read_pickle('./data10y_predict_pickle/024850')
test[test.index.year == 2018]
# Out:
#               yhat     y
# ds
# 2018-01-02  629.25   742
# 2018-01-03  625.56   738
# 2018-01-04  621.57   737
# 2018-01-05  616.15   757
# 2018-01-08  607.43   750
# 2018-01-09  605.07   742
# 2018-01-10  604.09   736
# 2018-01-11  603.00   720
# 2018-01-12  600.55   717
# 2018-01-15  600.45   728
# 2018-01-16  600.60   713
# 2018-01-17  601.83   716
# 2018-01-18  602.59   722
# 2018-01-19  601.61   726
# 2018-01-22  603.32   724
# 2018-01-23  603.20   725
# 2018-01-24  603.74   715
# 2018-01-25  603.43   727
# 2018-01-26  601.05   744
# 2018-01-29  597.02   744
# 2018-01-30  594.69   750
# 2018-01-31  592.98   750
# 2018-12-05  542.27   803
# 2018-12-06  546.56  null
# 2018-12-07  549.48  null
# 2018-12-08  553.05  null
# 2018-12-09  557.94  null
# 2018-12-10  564.64  null
# 2018-12-11  569.42  null
# 2018-12-12  574.96  null
# 2018-12-13  579.69  null
# 2018-12-14  582.28  null
# 2018-12-15  584.81  null
# 2018-12-16  587.93  null
# 2018-12-17  592.19  null
# ...

# %%
import pandas as pd
test = pd.read_pickle('./data10y_predict_pickle/008500')

# %%
target = test.index[test.y == 'null'][90]
target
# Out:
# Timestamp('2019-03-05 00:00:00')

# %%
test.to_json()
# Out:
# '{"yhat":{"1199232000000":20572.18,"1199318400000":20506.36,"1199404800000":20418.77,"1199664000000":20259.4,"1199750400000":20192.37,"1199836800000":20132.11,"1199923200000":20068.3,"1200009600000":19985.7,"1200268800000":19856.94,"1200355200000":19804.36,"1200441600000":19760.09,"1200528000000":19713.43,"1200614400000":19648.74,"1200873600000":19574.38,"1200960000000":19538.95,"1201046400000":19510.8,"1
# 2
# 0
# 0
# 0
# 0
# 0
# 0
# "
# :
# {
# "
# y
# h
# a
# t
# "
# :
# 2
# 0
# 5
# 7
# 2
# .
# 1
# 8
# ,
# "
# y
# "
# :
# 2
# 0
# 4
# 0
# 0
# .
# 0
# }
# ,
# "
# 1
# 1
# 9
# 9
# 3
# 1
# 8
# 4
# 0
# 0
# 0
# 0
# 0
# "
# :
# {
# "
# y
# h
# a
# t
# "
# :
# 2
# 0
# 5
# 0
# 6
# .
# 3
# 6
# ,
# "
# y
# "
# :
# 2
# 0
# 3
# 0
# 0
# .
# 0
# }
# ,
# "
# 1
# 1
# 9
# 9
# 4
# 0
# 4
# 8
# 0
# 0
# 0
# 0
# 0
# "
# :
# {
# "
# y
# h
# a
# t
# "
# :
# 2
# 0
# 4
# 1
# 8
# .
# 7
# 7
# ,
# "
# y
# "
# :
# 1
# 9
# 9
# 0
# 0
# .
# 0
# }
# ,
# "
# 1
# 1
# 9
# 9
# 6
# 6
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# "
# :
# {
# "
# y
# h
# a
# t
# "
# :
# 2
# 0
# 2
# 5
# 9
# .
# 4
# ,
# "
# y
# "
# :
# 2
# 0
# 0
# 0
# 0
# .
# 0
# }
# ,
# "
# 1
# 1
# 9
# 9
# 7
# 5
# 0
# 4
# 0
# 0
# 0
# 0
# 0
# "
# :
# {
# "
# y
# h
# a
# t
# "
# :
# 2
# 0
# 1
# 9
# 2
# .
# 3
# 7
# ,
# "
# y
# "
# :
# 1
# 9
# 9
# 0
# 0
# .
# 0
# }
# ,
# "
# 1
# 1
# 9
# 9
# 8
# 3
# 6
# 8
# 0
# 0
# 0
# 0
# 0
# "
# :
# {
# "
# y
# h
# ...

# %%
target - pd.DateOffset(days=1)
# Out:
# Timestamp('2019-03-04 00:00:00')

# %%
value1 = test.y[:target].tolist()
value1_new = ["" if x == 'null' else x for x in value1]
value1_new[-100:]
# Out:
# [16700.0,
#  17700.0,
#  18500.0,
#  18850.0,
#  19200.0,
#  19250.0,
#  19750.0,
#  19000.0,
#  18800.0,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %% [markdown]
# ### Find 90th null value(3 month)

# %%
test[-400:-350]
# Out:
#                 yhat      y
# ds
# 2018-10-17  18708.49  16750
# 2018-10-18  18670.87  16900
# 2018-10-19  18612.29  17600
# 2018-10-22  18540.51  17700
# 2018-10-23  18501.54  17750
# 2018-10-24  18468.16  16500
# 2018-10-25  18429.77  17200
# 2018-10-26  18370.85  17000
# 2018-10-29  18300.74  16000
# 2018-10-30  18263.15  15300
# 2018-10-31  18231.47  15800
# 2018-11-01  18195.03  16250
# 2018-11-02  18138.20  16500
# 2018-11-05  18074.20  16050
# 2018-11-06  18038.23  16200
# 2018-11-07  18007.82  16050
# 2018-11-08  17972.19  16600
# 2018-11-09  17915.68  16600
# 2018-11-12  17849.39  16600
# 2018-11-13  17811.64  16550
# 2018-11-14  17779.03  16450
# 2018-11-15  17740.89  16350
# 2018-11-16  17681.69  16750
# 2018-11-19  17607.83  16650
# 2018-11-20  17568.32  16650
# 2018-11-21  17534.65  16250
# 2018-11-22  17496.34  16700
# 2018-11-23  17438.03  17700
# 2018-11-26  17374.63  18500
# 2018-11-27  17341.54  18850
# 2018-11-28  17315.84  19200
# 2018-11-29  17287.02  19250
# ...

# %%
test.y[test.y == 'null']
# Out:
# ds
# 2018-12-05    null
# 2018-12-06    null
# 2018-12-07    null
# 2018-12-08    null
# 2018-12-09    null
# 2018-12-10    null
# 2018-12-11    null
# 2018-12-12    null
# 2018-12-13    null
# 2018-12-14    null
# 2018-12-15    null
# 2018-12-16    null
# 2018-12-17    null
# 2018-12-18    null
# 2018-12-19    null
# 2018-12-20    null
# 2018-12-21    null
# 2018-12-22    null
# 2018-12-23    null
# 2018-12-24    null
# 2018-12-25    null
# 2018-12-26    null
# 2018-12-27    null
# 2018-12-28    null
# 2018-12-29    null
# 2018-12-30    null
# 2018-12-31    null
# 2019-01-01    null
# 2019-01-02    null
# 2019-01-03    null
#               ...
# 2019-11-05    null
# 2019-11-06    null
# 2019-11-07    null
# 2019-11-08    null
# 2019-11-09    null
# 2019-11-10    null
# 2019-11-11    null
# 2019-11-12    null
# 2019-11-13    null
# 2019-11-14    null
# 2019-11-15    null
# 2019-11-16    null
# 2019-11-17    null
# 2019-11-18    null
# 2019-11-19    null
# 2019-11-20    null
# ...

# %%
test.y[test.y == 'null'][0]
# Out:
# 'null'

# %% [markdown]
# ### 90th Index Value

# %%
test.index[test.y == 'null'][90]
# Out:
# Timestamp('2019-03-05 00:00:00')

# %%
test[:test.index[test.y == 'null'][90]]
# Out:
#                 yhat      y
# ds
# 2008-01-02  20572.18  20400
# 2008-01-03  20506.36  20300
# 2008-01-04  20418.77  19900
# 2008-01-07  20259.40  20000
# 2008-01-08  20192.37  19900
# 2008-01-09  20132.11  19900
# 2008-01-10  20068.30  19400
# 2008-01-11  19985.70  19900
# 2008-01-14  19856.94  19900
# 2008-01-15  19804.36  19300
# 2008-01-16  19760.09  18950
# 2008-01-17  19713.43  18750
# 2008-01-18  19648.74  18800
# 2008-01-21  19574.38  19000
# 2008-01-22  19538.95  18250
# 2008-01-23  19510.80  18150
# 2008-01-24  19478.99  18400
# 2008-01-25  19427.68  18300
# 2008-01-28  19383.39  18600
# 2008-01-29  19354.52  18650
# 2008-01-30  19331.29  18600
# 2008-01-31  19302.90  18650
# 2008-02-01  19253.67  18750
# 2008-02-04  19210.04  18600
# 2008-02-05  19180.46  18650
# 2008-02-11  19042.10  18600
# 2008-02-12  19017.56  18500
# 2008-02-13  19000.29  18550
# 2008-02-14  18979.84  18600
# 2008-02-15  18940.84  18750
# ...              ...    ...
# 2019-02-04  15436.95   null
# ...

# %%
test[:test.index[test.y == 'null'][90]].shape
# Out:
# (2790, 2)

# %% [markdown]
# ### 90th Y value

# %%
test.y[:test.index[test.y == 'null'][90]].shape
# Out:
# (2790,)

# %%
target = test.index[test.y == 'null'][90]
test.y[:target].shape
# Out:
# (2790,)

# %% [markdown]
# ### 90th index

# %%
target = test.index[test.y == 'null'][90]
labels = test[:target].index.strftime('%Y-%m-%d').tolist()
labels[-10:]
# Out:
# ['2019-02-24',
#  '2019-02-25',
#  '2019-02-26',
#  '2019-02-27',
#  '2019-02-28',
#  '2019-03-01',
#  '2019-03-02',
#  '2019-03-03',
#  '2019-03-04',
#  '2019-03-05']

# %%
labels = test.index.strftime('%Y-%m-%d').tolist()
value1 = test.y.tolist()
value2 = test.yhat.tolist()

# %%
# Out:
#   File "<ipython-input-17-915f63161bc9>", line 1
#     value1.['null']
#            ^
# SyntaxError: invalid syntax
